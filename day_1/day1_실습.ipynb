# %% [markdown]
# <a href="https://colab.research.google.com/github/PEBpung/TotochTeam1/blob/main/day1_%ED%85%90%EC%84%9C(Tensor).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 이웃집 토토치 파이토치 : Day 1

# %% [markdown]
# 📢 해당 게시물은 파이토치 공식 튜토리얼 중 파이토치(PyTorch) 시작하기를 읽고 직접 작성해보는 실습 노트북입니다.

# %% [markdown]
# #### 목차
# 1. 탠서(TENSOR)
#     1. 텐서(tensor) 초기화
#     2. 텐서의 속성(Attribute)
#     3. 텐서 연산(Operation)
#     4. NumPy 변환(Bridge)
# 2. Autograd
#     1. Tensor, Function과 연산그래프(Computational graph)
#     2. 변화도(Gradient) 계산하기
#     3. 변화도 추적 멈추기
#     4. 연산 그래프에 대한 추가 정보
#     5. 선택적으로 읽기(Optional Reading): 텐서 변화도와 야코비안 곱 (Jacobian Product)
#     6. [실습] Backpropagation with Autograd
# 3. DATASET과 DATALOADER
#     1. 데이터셋 불러오기
#     2. 데이터셋을 순회하고 시각화하기
#     3. 파일에서 사용자 정의 데이터셋 만들기
#     4. DataLoader로 학습용 데이터 준비하기
#     5. DataLoader를 통해 순회하기

# %% [markdown]
# ## 1. 텐서 (Tensor)

# %%
import torch
import numpy as np

# %% [markdown]
# ### 텐서(tensor) 초기화

# %% [markdown]
# **데이터로부터 직접(directly) 생성하기**

# %%
data = [[1, 2],[3, 4]]
x_data = torch.tensor(data)
x_data

# %% [markdown]
# **NumPy 배열로부터 생성하기**

# %%
np_array = np.array(data)
x_np = torch.from_numpy(np_array)
x_np

# %% [markdown]
# **다른 텐서로부터 생성하기**

# %%
# x_data의 속성을 유지합니다.
x_ones = torch.ones_like(x_data) 
print(f"Ones Tensor: \n {x_ones} \n")

# x_data의 속성을 덮어씁니다.
x_rand = torch.rand_like(x_data, dtype=torch.float) 
print(f"Random Tensor: \n {x_rand} \n")

# %% [markdown]
# **무작위(random) 또는 상수(constant) 값을 사용하기:**

# %%
shape = (2,3,)
rand_tensor = torch.rand(shape)
ones_tensor = torch.ones(shape)
zeros_tensor = torch.zeros(shape)

print(f"Random Tensor: \n {rand_tensor} \n")
print(f"Ones Tensor: \n {ones_tensor} \n")
print(f"Zeros Tensor: \n {zeros_tensor}")

# %% [markdown]
# ### 텐서의 속성(Attribute)

# %%
tensor = torch.rand(3,4)

############################
# 밑줄 친 곳을 채워주세요! #
############################

print(f"Shape of tensor: {___}")
print(f"Datatype of tensor: {___}")
print(f"Device tensor is stored on: {___}")

# %% [markdown]
# ### 텐서 연산(Operation)

# %% [markdown]
# <div class="alert alert-warning">
#     <p><b>Q. 텐서를 사용하면 어떤 점이 좋을까요??</b></p>
#     <p>👉 (여기에 답을 입력해 주세요)</p>
# </div>

# %%
# GPU가 존재하면 텐서를 이동합니다
if torch.cuda.is_available():
  tensor = tensor.to('cuda')

# %% [markdown]
# NumPy식의 표준 인덱싱과 슬라이싱:

# %%
data = [[1, 2, 3],
         [4, 5, 6],
         [7, 8, 9]]
t_data = torch.tensor(data)

############################
# 밑줄 친 곳을 채워주세요! #
############################

print('2번째 행 출력: ',___)
print('t_data에서 5를 출력: ', ___)
print('마지막 column 출력:', ___)
t_data[___] = 0
print('3번째 column을 0으로 만들기:')
print(t_data)

# %% [markdown]
# **텐서 합치기**

# %%
t1 = torch.cat([tensor, tensor, tensor], dim=1)
print(t1)

# %% [markdown]
# **산술 연산(Arithmetic operations)**

# %%
tensor = torch.rand(3,4)

# %%
# 두 텐서 간의 행렬 곱(matrix multiplication)을 계산합니다. y1, y2, y3은 모두 같은 값을 갖습니다.
y1 = tensor @ tensor.T
y2 = tensor.matmul(tensor.T)

y3 = torch.rand_like(tensor)
torch.matmul(tensor, tensor.T, out=y3)
print(y1)
print(y2)
print(y3)

print('-- '*15)
# 요소별 곱(element-wise product)을 계산합니다. z1, z2, z3는 모두 같은 값을 갖습니다.
z1 = tensor * tensor
z2 = tensor.mul(tensor)

z3 = torch.rand_like(tensor)
torch.mul(tensor, tensor, out=z3)
print(z1)
print(z2)
print(z3)

# %% [markdown]
# <div class="alert alert-warning">
#     <p><b>Q. 행렬 곱(matrix multiplication)과 요소별 곱(element-wise product)의 차이점이 뭘까요??</b></p>
#     <p>👉 (여기에 답을 입력해 주세요)</p>
# </div>

# %% [markdown]
# **단일-요소(single-element)**

# %%
agg = tensor.sum()
agg_item = agg.item()
print(agg_item, type(agg_item))

# %% [markdown]
# **텐서차원 축소/확장(Squeeze/Unsqueeze) 연산**

# %%
# Squeeze/Unsqueeze
x = torch.rand((1,1,3,4))
y = x.squeeze()
print(y.size())
print(y.unsqueeze(1).size())

# %% [markdown]
# <div class="alert alert-warning">
#     <p><b>Q. Squeeze와 Unsqueeze는 어떤 경우에 사용 될까요? 자유롭게 생각해보죠!</b></p>
#     <p>👉 (여기에 답을 입력해 주세요)</p>
# </div>

# %% [markdown]
# **스태킹(Stacking)**

# %%
x = torch.FloatTensor([1, 4])
y = torch.FloatTensor([2, 5])
z = torch.FloatTensor([3, 6])

print(torch.stack([x, y, z]))

# %% [markdown]
# ### 넘파이(Numpy)

# %% [markdown]
# **텐서를 NumPy 배열로 변환하기**

# %%
t = torch.ones(5)
print(f"t: {t}")
n = t.numpy()
print(f"n: {n}")

# %% [markdown]
# 텐서의 변경 사항이 NumPy 배열에 반영됩니다.

# %%
t.add_(1)
print(f"t: {t}")
print(f"n: {n}")

# %% [markdown]
# **NumPy 배열을 텐서로 변환하기**

# %%
n = np.ones(5)
t = torch.from_numpy(n)

# %% [markdown]
# NumPy 배열의 변경 사항이 텐서에 반영됩니다.

# %%
np.add(n, 1, out=n)
print(f"t: {t}")
print(f"n: {n}")

# %% [markdown]
# # 2. Autograd

# %% [markdown]
# 간단 이미지 분류 모델 학습

# %%
random_seed = 77
torch.manual_seed(random_seed)

# %% [markdown]
# ### 1) 데이터 준비하기

# %%
model = torch.nn.Sequential(
    torch.nn.Linear(6, 1),
    torch.nn.Flatten()
)
data = torch.rand(2, 6)
labels = torch.rand(2, 1)
labels
# Out:
# tensor([[0.6972],
#         [0.5420]])

# %% [markdown]
# 모델은  torchvision 에서 미리 학습된 resnet18 모델을 불러옵니다. 3채널짜리 높이와 넓이가 64인 이미지 하나를 표현하는 무작위의 데이터 텐서를 생성하고, 이에 상응하는 label(정답) 을 무작위 값으로 초기화합니다.

# %% [markdown]
# ### 2) 순전파 (Forward Propagation)

# %%
prediction = model(data) # 순전파 단계(forward pass)
prediction
# Out:
# tensor([[-0.0071],
#         [-0.0564]], grad_fn=<AddmmBackward>)

# %%
layer = model[0]
print(f'Result: y = {layer.bias.item()} + {layer.weight[:, 0].item()} x + {layer.weight[:, 1].item()} x^2 + {layer.weight[:, 2].item()} x^3')
# Out:
# Result: y = 0.1343376636505127 + -0.16990196704864502 x + -0.1749909669160843 x^2 + -0.07995617389678955 x^3

# %% [markdown]
# 순전파 단계에서는 입력(input) 데이터를 모델의 각 층(layer)에 통과시켜 예측값(prediction)을 생성합니다.

# %% [markdown]
# ### 3) 손실함수 (loss) 계산하기

# %%
loss = (prediction - labels).sum() 
print(loss)
loss.backward() # 역전파 단계(backward pass)
# Out:
# tensor(-1.3027, grad_fn=<SumBackward0>)

# %% [markdown]
# - 모델의 예측값(prediction)과 그에 해당하는 정답(label)의 차이를 합하여 오차(error, 손실(loss) )를 계산하였습니다. 손실함수를 구하는 방법은 다양하지만 이번글에서는 간단하게 차이값으로만 구하도록 하겠습니다.
#
# -  오차 텐서(error tensor)에 .backward() 를 호출하면 역전파가 시작되며, 그 다음 Autograd가 매개변수(parameter)의 .grad 속성(attribute)에, 모델의 각 매개변수에 대한 변화도(gradient)를 계산하고 저장합니다.

# %% [markdown]
# ### 4) 옵티마이저 설정

# %%
optim = torch.optim.SGD(model.parameters(), lr=1e-2, momentum=0.9)

# %% [markdown]
# - 학습율(learning rate) 0.1과 모멘텀(momentum) 0.9를 갖는 SGD로 옵티마이즈를 설정하였으며, 옵티마이저(optimizer)에 모델의 모든 매개변수(models.parameters())를 등록합니다.

# %% [markdown]
# ### 5) 경사하강법

# %%
optim.step() # 경사하강법(gradient descent)

# %%
layer = model[0]
print(f'Result: y = {layer.bias.item()} + {layer.weight[:, 0].item()} x + {layer.weight[:, 1].item()} x^2 + {layer.weight[:, 2].item()} x^3')
# Out:
# Result: y = 0.11433766782283783 + -0.18834170699119568 x + -0.18366260826587677 x^2 + -0.08588283509016037 x^3

# %%
prediction = model(data) # 순전파 단계(forward pass)
prediction
# Out:
# tensor([[-0.0694],
#         [-0.1211]], grad_fn=<AddmmBackward>)

# %% [markdown]
# - step 을 호출하여 경사하강법(gradient descent)을 시작합니다. 옵티마이저는 .grad 에 저장된 기울기(gradient)에 따라 각 매개변수를 조정(adjust)합니다.

# %%
layer = model[0]
print(f'------------------------------------------')
print(f'Result: y = {layer.bias.item()} + {layer.weight[:, 0].item()} x + {layer.weight[:, 1].item()} x^2 + {layer.weight[:, 2].item()} x^3')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-9e62dfeab5e8> in <module>
# ----> 1 linear_layer = model[0]
#       2 print(f'Result: y = {linear_layer.bias.item()} + {linear_layer.weight[:, 0].item()} x + {linear_layer.weight[:, 1].item()} x^2 + {linear_layer.weight[:, 2].item()} x^3')
#
# TypeError: 'ResNet' object is not subscriptable

# %% [markdown]
# ## 실습문제
# 다음과 같은 연산 그래프를 직접 구현하면서 Autograd를 이해해보는 시간을 갖겠습니다.
# x는 초기 값으로 2x2의 1로 채워진 행렬을 사용할 것입니다.
#
# <img src="./img/ex1.jpg" width='600'>

# %%
x = torch.ones(2, 2)
print(x)
print(x.requires_grad)
print('-'*10)

x = torch.ones(2, 2, requires_grad=True)
print(x)
print(x.requires_grad)

# %% [markdown]
# <div class="alert alert-warning">
#     <p><b>Q. requires_grad는 어떤 역할을 하는 파라미터일까요?</b></p>
#     <p>👉 (여기에 답을 입력해 주세요)</p>
# </div>

# %%
############################
# 밑줄 친 곳을 채워주세요! #
############################

y = ___
print(y)
print(y.requires_grad)

# %%
print(y.grad_fn)

# %%
############################
# 밑줄 친 곳을 채워주세요! #
############################

z = ___
out = z.mean()
print(z)
print(out)

# %% [markdown]
# ### Gradient, 경사/기울기

# %% [markdown]
# 역전파를 해보겠습니다. out.backward()과 out.backward(torch.Tensor([1.0]))은 동일하게 동작합니다.

# %%
out.backward()

# %%
print(x.grad)
# Out:
# tensor([[4.5000, 4.5000],
#         [4.5000, 4.5000]])

# %%
from torch.autograd import Variable

#vector-Jacobian 곱의 예시
x = torch.randn(3)
x = Variable(x, requires_grad=True)

y = x * 2
i = 0
while y.data.norm() < 1000:
    y = y * 2
    i += 1
    
print(i * 2)
print(y)
# Out:
# 20
# tensor([ -635.0923, -1457.1912,  -662.2779], grad_fn=<MulBackward0>)

# %%
gradients = torch.FloatTensor([0.1, 1.0, 0.0001])
y.backward(gradients)

print(x.grad)
# Out:
# tensor([1.0240e+02, 1.0240e+03, 1.0240e-01])
